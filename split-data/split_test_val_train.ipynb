# %%
import numpy as np
import pandas as pd
import tools
import pickle

# %%
class splitsville():
    
    def __init__(self):
        self.split_years={}
        self.n_years_list = {'test':[], 'val':[], 'train':[]}
        self.dates = {'train':{},'val':{}, 'test':{}}
        with open(tools.get_main_dir()+'ri-calc.csv') as f:
            self.df = pd.read_csv(f)
    
    #___________________________________________________________________________
    def prepare_peakflows(self, pf, peakflows):

        # Don't include years before 1980
        if int(str(np.array(peakflows.iloc[pf,:])[0]).split('-')[0]) < 1980:
            return pd.to_datetime('1900-01-01')
        
         #  some of the early months/days are not known, so are input as zero!!!
         #  Just put a month/day so the the water year is the provided calendar year.
        try:
            date_of_peak = pd.to_datetime(np.array(peakflows.iloc[pf,:])[0])
        except:
            datestr=str(np.array(peakflows.iloc[pf,:])[0]).split('-')
            if datestr[1] == '00':
                if datestr[2] == '00':
                    date_of_peak = pd.to_datetime(datestr[0]+'-12-31')
                else:
                    date_of_peak = pd.to_datetime('1900-01-01')
            else:
                date_of_peak = pd.to_datetime('1900-01-01')
                
        return date_of_peak
    #___________________________________________________________________________    
    def split_year_to_test_val_train(self, annual_peak, ri, water_year_of_peak, basin_str):
        # Now split up the years into train (25-75)
        try:   ### Annual Peak might be NaN or some other non-numeric. So skip...
            if isinstance(annual_peak, str):
                annual_peak = float(annual_peak.strip())
            if float(annual_peak) < ri[5.0]:
                if int(water_year_of_peak) > 1990 and int(water_year_of_peak) < 2015:
                    self.split_years[basin_str]['train'].append(int(water_year_of_peak))
        except:
            print('basin_str', basin_str)
            print('annual_peak{}annual_peak'.format(annual_peak))
            print('type(annual_peak)', type(annual_peak))
            print('float(annual_peak)', float(annual_peak))
            print('water_year_of_peak', water_year_of_peak)
            print('type(water_year_of_peak)', type(water_year_of_peak))
            print('int(water_year_of_peak)', int(water_year_of_peak))
            print('self.split_years[basin_str][train]', self.split_years[basin_str]['train'])
            return 0

        try:
            if isinstance(annual_peak, str):
                annual_peak = float(annual_peak.strip())
            if float(annual_peak) >= ri.loc[10.0] and annual_peak < ri[25.0]:
                self.split_years[basin_str]['val'].append(int(water_year_of_peak))
        except:
            print('basin_str', basin_str)
            print('annual_peak{}annual_peak'.format(annual_peak))
            print('type(annual_peak)', type(annual_peak))
            print('float(annual_peak)', float(annual_peak))
            print('water_year_of_peak', water_year_of_peak)
            print('type(water_year_of_peak)', type(water_year_of_peak))
            print('int(water_year_of_peak)', int(water_year_of_peak))
            print('self.split_years[basin_str][val]', self.split_years[basin_str]['val'])
            return 0

        try:
            if isinstance(annual_peak, str):
                annual_peak = float(annual_peak.strip())
            if float(annual_peak) >= ri[25.0]:
                self.split_years[basin_str]['test'].append(int(water_year_of_peak))
        except:
            print('basin_str', basin_str)
            print('annual_peak{}annual_peak'.format(annual_peak))
            print('type(annual_peak)', type(annual_peak))
            print('float(annual_peak)', float(annual_peak))
            print('water_year_of_peak', water_year_of_peak)
            print('type(water_year_of_peak)', type(water_year_of_peak))
            print('int(water_year_of_peak)', int(water_year_of_peak))
            print('self.split_years[basin_str][test]', self.split_years[basin_str]['test'])
            return 0
        
        return 1
    
    #___________________________________________________________________________    
    def clean_test_val_train_lists(self, basin_str):
        # We need to go through both the train and test sets
        # and remove years that cannot maintain a 1 year gap.
        # For instance, we can not train 1980 and test 1981

        for i in self.split_years[basin_str]['train']:
            if i-1 in self.split_years[basin_str]['test']:
                self.split_years[basin_str]['train'].remove(i)
                
        for i in self.split_years[basin_str]['test']:
            if i-1 in self.split_years[basin_str]['train']:
                self.split_years[basin_str]['train'].remove(i-1)
                
        # Take only N years for training
        self.split_years[basin_str]['train'] = self.split_years[basin_str]['train'][0:13]
                
    #___________________________________________________________________________
    def append_dates(self, basin_str):
        for split_type in ['test', 'train', 'val']:
            for i in self.split_years[basin_str][split_type]:
                self.dates[split_type][basin_str]['start_dates'].append(pd.to_datetime('01/10/{}'.format(i-1)))
                self.dates[split_type][basin_str]['end_dates'].append(pd.to_datetime('30/09/{}'.format(i)))
        
    #___________________________________________________________________________
    def summarize_dates(self, basin_str):
        print(basin_str)
        print('_____________________________')
        for split_type in ['test', 'train', 'val']:
            self.n_years_list[split_type].append(len(self.split_years[basin_str][split_type]))
            print('Number of {} years'.format(split_type), len(self.split_years[basin_str][split_type]))
            print('{} years'.format(split_type), self.split_years[basin_str][split_type])
        print('\n')
    
    #___________________________________________________________________________
    def do_splits(self):
        for basin in self.df.gauge_id:
            basin_str = tools.gauge_id_str(basin)
            
            for split_type in ['test', 'train', 'val']:
                self.dates[split_type][basin_str] = {'start_dates':[], 'end_dates':[]}
            
        #    print(basin_str)

            ri = tools.read_b17(basin_str)
        #    print(ri)

            peakflows = tools.read_peak_flows(basin_str)

            low_flow_cutoff = tools.closest_value(1.1,ri.index.values)

            # Loop through the peaks, and assign the years to either test or train
            self.split_years[basin_str] = {'test':[], 'val':[], 'train':[]}

            for pf in range(peakflows.shape[0]):

                date_of_peak = self.prepare_peakflows(pf, peakflows)
                if date_of_peak.year < 1980:
                    continue
                
                annual_peak = np.array(peakflows.iloc[pf,:])[1]

                water_year_of_peak = tools.get_water_year(date_of_peak.year, date_of_peak.month)

                good_split = self.split_year_to_test_val_train(annual_peak,ri,water_year_of_peak,basin_str)
                if good_split == 0:
                    continue

                self.clean_test_val_train_lists(basin_str)

            self.append_dates(basin_str)

            self.summarize_dates(basin_str)

    #___________________________________________________________________________
    def clean_start_end_lists(self):
        for basin in self.df.gauge_id:
            basin_str = tools.gauge_id_str(basin)
                        
            addsubtract = [-1, 1]

            for split_type in ['test', 'train', 'val']:
                temp_dates = self.dates[split_type][basin_str]

                for i, start_end in enumerate(['start_dates','end_dates']):
                    tempdays = []
                    tempdayyears = []
                    for d in temp_dates[start_end]:
                        tempdayyears.append(d.year)
                    for d in temp_dates[start_end]:
                        if start_end == 'start_dates':
                            if len(tempdays) == 0:
                                tempdays.append(d)
                                continue
                        if d.year + addsubtract[i] in tempdayyears:
                            continue
                        else:
                            tempdays.append(d)
                    self.dates[split_type][basin_str][start_end] = tempdays

#                 enddays = []
#                 enddayyears = []
#                 for d in temp_dates['end_dates']:
#                     enddayyears.append(d.year)
#                 for d in temp_dates['end_dates']:
#                     if d.year < 1981:
#                         continue
#                     if len(enddays) == 0:
#                         enddays.append(d)
#                         continue
#                     if d.year + 1 in enddayyears:
#                         continue
#                     else:
#                         enddays.append(d)
#                 self.dates[split_type][basin_str]['end_dates'] = enddays

# %%
split_these = splitsville()

# %%
split_these.do_splits()
# Out:
# 01466500
# _____________________________
# Number of test years 2
# test years [2004, 2011]
# Number of train years 13
# train years [1992, 1993, 1994, 1995, 1996, 1997, 1999, 2000, 2001, 2002, 2006, 2008, 2009]
# Number of val years 1
# val years [1991]
#
#
# 10244950
# _____________________________
# Number of test years 3
# test years [1983, 1985, 2005]
# Number of train years 13
# train years [1991, 1992, 1993, 1994, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2007]
# Number of val years 2
# val years [1984, 2011]
#
#
# 10172800
# _____________________________
# Number of test years 1
# test years [1998]
# Number of train years 13
# train years [1991, 1992, 1993, 1994, 1996, 2000, 2001, 2002, 2003, 2004, 2007, 2008, 2009]
# Number of val years 6
# val years [1983, 1984, 1986, 1995, 2005, 2011]
#
#
# 09378630
# _____________________________
# Number of test years 0
# test years []
# Number of train years 13
# train years [1991, 1992, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004]
# Number of val years 5
# val years [1980, 1983, 1988, 2005, 2016]
#
#
# 13018300
# _____________________________
# Number of test years 2
# test years [1986, 2017]
# Number of train years 13
# train years [1991, 1992, 1993, 1994, 1995, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005]
# Number of val years 2
# val years [1996, 1997]
#
#
# 09066300
# _____________________________
# Number of test years 3
# test years [2003, 2011, 2019]
# Number of train years 13
# train years [1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2001, 2005, 2006, 2007]
# Number of val years 0
# val years []
#
#
# 09047700
# _____________________________
# Number of test years 2
# test years [1995, 2014]
# Number of train years 13
# train years [1991, 1992, 1993, 1998, 1999, 2000, 2001, 2002, 2004, 2005, 2006, 2007, 2008]
# Number of val years 3
# val years [1983, 1996, 2011]
#
#
# 10023000
# _____________________________
# Number of test years 0
# test years []
# Number of train years 13
# train years [1991, 1992, 1993, 1994, 1995, 1996, 1997, 1999, 2000, 2001, 2002, 2003, 2004]
# Number of val years 1
# val years [2011]
#
#
# 13083000
# _____________________________
# Number of test years 3
# test years [1984, 2004, 2017]
# Number of train years 13
# train years [1991, 1992, 1993, 1994, 1995, 1996, 1998, 1999, 2000, 2001, 2002, 2007, 2008]
# Number of val years 1
# val years [1980]
#
#
# 10310500
# _____________________________
# Number of test years 3
# test years [1997, 2006, 2017]
# Number of train years 13
# train years [1991, 1992, 1993, 1994, 1995, 1999, 2000, 2001, 2002, 2003, 2004, 2008, 2009]
# Number of val years 0
# val years []
#
#
# 01484100
# _____________________________
# Number of test years 1
# test years [2011]
# Number of train years 13
# train years [1991, 1992, 1993, 1995, 1996, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005]
# Number of val years 6
# val years [1984, 1997, 2010, 2013, 2016, 2017]
#
#
# 09034900
# _____________________________
# Number of test years 2
# test years [1988, 2010]
# Number of train years 13
# train years [1991, 1992, 1993, 1994, 1996, 1998, 1999, 2000, 2001, 2002, 2004, 2005, 2006]
# Number of val years 0
# val years []
#
#
# 08271000
# _____________________________
# Number of test years 0
# test years []
# Number of train years 13
# train years [1992, 1993, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2006, 2007]
# Number of val years 3
# val years [1984, 1991, 1995]
#
#
# 04105700
# _____________________________
# Number of test years 2
# test years [2008, 2015]
# Number of train years 13
# train years [1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003]
# Number of val years 3
# val years [1986, 1989, 2018]
#
#
# 10249300
# _____________________________
# Number of test years 2
# test years [1983, 2005]
# Number of train years 13
# train years [1991, 1992, 1993, 1994, 1996, 1997, 1999, 2000, 2002, 2003, 2007, 2008, 2009]
# Number of val years 1
# val years [1998]
#
#
# 09066000
# _____________________________
# Number of test years 1
# test years [2019]
# Number of train years 13
# train years [1991, 1992, 1993, 1994, 1996, 1998, 1999, 2001, 2002, 2004, 2005, 2006, 2007]
# Number of val years 3
# val years [1983, 1995, 2011]
#
#
# 09066200
# _____________________________
# Number of test years 1
# test years [2010]
# Number of train years 13
# train years [1991, 1992, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2002, 2004, 2005, 2006]
# Number of val years 3
# val years [1981, 2001, 2011]
#
#
# 01118300
# _____________________________
# Number of test years 1
# test years [2010]
# Number of train years 13
# train years [1991, 1992, 1993, 1995, 1996, 1997, 1999, 2000, 2002, 2003, 2005, 2008, 2012]
# Number of val years 6
# val years [1982, 1987, 2004, 2006, 2007, 2014]
#
#
# 01486000
# _____________________________
# Number of test years 0
# test years []
# Number of train years 13
# train years [1991, 1992, 1993, 1995, 1996, 1997, 2002, 2003, 2006, 2007, 2008, 2009, 2010]
# Number of val years 4
# val years [1985, 1998, 2005, 2016]
#
#
# 08267500
# _____________________________
# Number of test years 2
# test years [1995, 2005]
# Number of train years 13
# train years [1992, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2007, 2009, 2010, 2011, 2012]
# Number of val years 1
# val years [1991]
#
#
# 09035900
# _____________________________
# Number of test years 3
# test years [1995, 2010, 2011]
# Number of train years 13
# train years [1991, 1992, 1993, 1998, 1999, 2000, 2001, 2002, 2004, 2005, 2006, 2007, 2008]
# Number of val years 1
# val years [2019]
#
#
# 07083000
# _____________________________
# Number of test years 5
# test years [1984, 1985, 1995, 1999, 2010]
# Number of train years 13
# train years [1991, 1992, 1993, 1997, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2012]
# Number of val years 1
# val years [2019]
#
#
# 12073500
# _____________________________
# Number of test years 3
# test years [1991, 1997, 2011]
# Number of train years 13
# train years [1993, 1994, 1995, 2000, 2001, 2003, 2004, 2005, 2006, 2007, 2009, 2013, 2014]
# Number of val years 2
# val years [1986, 2008]
#
#
# 10172700
# _____________________________
# Number of test years 1
# test years [1991]
# Number of train years 13
# train years [1993, 1994, 1995, 1996, 1997, 1999, 2000, 2001, 2003, 2004, 2006, 2007, 2008]
# Number of val years 0
# val years []
#
#
# 10205030
# _____________________________
# Number of test years 3
# test years [1983, 1984, 1989]
# Number of train years 13
# train years [1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003]
# Number of val years 1
# val years [2010]
#
#
# 02102908
# _____________________________
# Number of test years 3
# test years [2008, 2016, 2017]
# Number of train years 13
# train years [1991, 1993, 1994, 1995, 1996, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005]
# Number of val years 2
# val years [1992, 2018]
#
#
# 01139800
# _____________________________
# Number of test years 3
# test years [1990, 2009, 2011]
# Number of train years 13
# train years [1993, 1994, 1995, 1997, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2013]
# Number of val years 2
# val years [1996, 2014]
#
#
# 02235200
# _____________________________
# Number of test years 2
# test years [2005, 2008]
# Number of train years 13
# train years [1991, 1992, 1993, 1994, 1996, 1997, 1998, 1999, 2000, 2002, 2003, 2010, 2011]
# Number of val years 4
# val years [1995, 2001, 2009, 2017]
#
#
# 06311000
# _____________________________
# Number of test years 1
# test years [2011]
# Number of train years 13
# train years [1991, 1992, 1993, 1994, 1997, 1998, 2000, 2001, 2002, 2003, 2004, 2005, 2006]
# Number of val years 1
# val years [2010]
#
#
# 09065500
# _____________________________
# Number of test years 2
# test years [2010, 2011]
# Number of train years 13
# train years [1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2004, 2005]
# Number of val years 2
# val years [1983, 1990]
#
#
# 01542810
# _____________________________
# Number of test years 2
# test years [1996, 2012]
# Number of train years 13
# train years [1991, 1992, 1993, 1994, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2007]
# Number of val years 0
# val years []
#
#
# 08377900
# _____________________________
# Number of test years 2
# test years [1991, 1997]
# Number of train years 13
# train years [1993, 1999, 2000, 2001, 2002, 2003, 2004, 2006, 2007, 2008, 2009, 2010, 2011]
# Number of val years 2
# val years [1995, 2013]
#
#
# 09210500
# _____________________________
# Number of test years 0
# test years []
# Number of train years 13
# train years [1991, 1992, 1993, 1994, 1996, 1997, 1998, 2000, 2001, 2002, 2003, 2004, 2005]
# Number of val years 4
# val years [1980, 1983, 1986, 1995]
#
#
# 09312600
# _____________________________
# Number of test years 2
# test years [1983, 1984]
# Number of train years 13
# train years [1991, 1992, 1994, 1995, 1996, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005]
# Number of val years 0
# val years []
#
#
# 03357350
# _____________________________
# Number of test years 2
# test years [1989, 2008]
# Number of train years 13
# train years [1991, 1992, 1993, 1994, 1995, 1996, 1999, 2000, 2003, 2004, 2005, 2006, 2010]
# Number of val years 3
# val years [2011, 2013, 2015]
#
#
# 10316500
# _____________________________
# Number of test years 1
# test years [2010]
# Number of train years 13
# train years [1991, 1992, 1993, 1994, 1998, 2000, 2001, 2002, 2004, 2007, 2008, 2012, 2013]
# Number of val years 8
# val years [1982, 1986, 1995, 1997, 2003, 2005, 2006, 2011]
#
#
# 10343500
# _____________________________
# Number of test years 1
# test years [1997]
# Number of train years 13
# train years [1991, 1992, 1993, 1994, 1995, 2000, 2001, 2002, 2003, 2004, 2005, 2007, 2008]
# Number of val years 4
# val years [1982, 1986, 1996, 2006]
# 08269000
# _____________________________
# Number of test years 0
# test years []
# Number of train years 13
# train years [1992, 1993, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2004, 2006, 2007]
# Number of val years 2
# val years [1984, 1991]
#
#
# 06409000
# _____________________________
# Number of test years 1
# test years [2002]
# Number of train years 13
# train years [1991, 1992, 1993, 1994, 1997, 2004, 2005, 2006, 2007, 2008, 2009, 2011, 2012]
# Number of val years 4
# val years [1996, 2000, 2003, 2010]
#
#
# 10234500
# _____________________________
# Number of test years 2
# test years [1984, 1995]
# Number of train years 13
# train years [1991, 1992, 1993, 1997, 1999, 2000, 2001, 2002, 2003, 2004, 2006, 2007, 2008]
# Number of val years 4
# val years [1983, 2005, 2011, 2019]
#
#
# 09404450
# _____________________________
# Number of test years 2
# test years [2011, 2013]
# Number of train years 13
# train years [1991, 1992, 1993, 1994, 1995, 1997, 2000, 2001, 2002, 2003, 2004, 2006, 2007]
# Number of val years 3
# val years [2012, 2014, 2016]
#
#
# 12447390
# _____________________________
# Number of test years 2
# test years [2006, 2017]
# Number of train years 13
# train years [1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003]
# Number of val years 1
# val years [1986]
#
#
# 06291500
# _____________________________
# Number of test years 1
# test years [2007]
# Number of train years 13
# train years [1991, 1992, 1993, 1994, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004]
# Number of val years 0
# val years []
#
#
# 04127997
# _____________________________
# Number of test years 1
# test years [2014]
# Number of train years 13
# train years [1991, 1993, 1994, 1995, 1996, 1997, 2000, 2001, 2002, 2003, 2004, 2005, 2006]
# Number of val years 2
# val years [1990, 2011]
#
#
# 01073000
# _____________________________
# Number of test years 4
# test years [1997, 2006, 2007, 2010]
# Number of train years 13
# train years [1991, 1992, 1993, 1994, 1995, 1999, 2000, 2001, 2002, 2003, 2012, 2013, 2014]
# Number of val years 2
# val years [1981, 1983]
#
#
# 10173450
# _____________________________
# Number of test years 2
# test years [2005, 2011]
# Number of train years 13
# train years [1991, 1992, 1993, 1994, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2007]
# Number of val years 3
# val years [1983, 2010, 2019]
#
#
# 06447500
# _____________________________
# Number of test years 3
# test years [1983, 1997, 2019]
# Number of train years 13
# train years [1991, 1992, 1993, 1995, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007]
# Number of val years 1
# val years [2011]
#
#
# 04043050
# _____________________________
# Number of test years 0
# test years []
# Number of train years 13
# train years [1991, 1992, 1993, 1994, 1995, 1996, 1997, 1999, 2000, 2002, 2003, 2004, 2005]
# Number of val years 4
# val years [1988, 1989, 1998, 2014]
#
#
# 01162500
# _____________________________
# Number of test years 0
# test years []
# Number of train years 13
# train years [1991, 1992, 1993, 1994, 1995, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004]
# Number of val years 2
# val years [1984, 1987]
#
#
# 06622700
# _____________________________
# Number of test years 3
# test years [1983, 2010, 2011]
# Number of train years 13
# train years [1991, 1992, 1993, 1994, 1996, 1998, 1999, 2001, 2002, 2004, 2006, 2007, 2008]
# Number of val years 2
# val years [1986, 2003]
#
#
# 10259000
# _____________________________
# Number of test years 1
# test years [2019]
# Number of train years 13
# train years [1991, 1992, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004]
# Number of val years 3
# val years [1983, 1993, 2005]
#
#
# 11180500
# _____________________________
# Number of test years 0
# test years []
# Number of train years 13
# train years [1991, 1992, 1993, 1994, 1996, 1997, 1999, 2000, 2001, 2002, 2003, 2004, 2005]
# Number of val years 3
# val years [1983, 1995, 1998]
#
#
# 04063700
# _____________________________
# Number of test years 2
# test years [1996, 2002]
# Number of train years 13
# train years [1992, 1993, 1994, 1998, 1999, 2000, 2004, 2005, 2006, 2007, 2008, 2009, 2010]
# Number of val years 1
# val years [1986]
#
#
# 03450000
# _____________________________
# Number of test years 3
# test years [1994, 2018, 2019]
# Number of train years 13
# train years [1991, 1992, 1997, 1999, 2000, 2001, 2002, 2003, 2005, 2006, 2007, 2008, 2009]
# Number of val years 2
# val years [2004, 2013]
#
#
# 06278300
# _____________________________
# Number of test years 1
# test years [2011]
# Number of train years 13
# train years [1991, 1992, 1993, 1994, 1996, 1997, 1998, 1999, 2000, 2001, 2004, 2006, 2007]
# Number of val years 3
# val years [1990, 1995, 2003]
#
#
# 04057800
# _____________________________
# Number of test years 2
# test years [1985, 2002]
# Number of train years 13
# train years [1991, 1993, 1994, 1995, 1997, 1998, 1999, 2000, 2005, 2006, 2007, 2008, 2009]
# Number of val years 3
# val years [1986, 1996, 2013]
#
#
# 09223000
# _____________________________
# Number of test years 1
# test years [1986]
# Number of train years 13
# train years [1991, 1992, 1994, 1995, 1998, 2000, 2001, 2002, 2003, 2004, 2006, 2007, 2008]
# Number of val years 2
# val years [1983, 1984]
#
#
# 04057510
# _____________________________
# Number of test years 2
# test years [1985, 1996]
# Number of train years 13
# train years [1991, 1992, 1993, 1994, 1998, 1999, 2000, 2002, 2003, 2004, 2005, 2006, 2007]
# Number of val years 1
# val years [1986]
#
#
# 03026500
# _____________________________
# Number of test years 2
# test years [1987, 1989]
# Number of train years 13
# train years [1992, 1993, 1994, 1995, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005]
# Number of val years 1
# val years [1991]
#
#
# 13161500
# _____________________________
# Number of test years 1
# test years [1984]
# Number of train years 13
# train years [1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003]
# Number of val years 3
# val years [1983, 2005, 2011]
#
#
# 06332515
# _____________________________
# Number of test years 0
# test years []
# Number of train years 13
# train years [1991, 1992, 1994, 1995, 1996, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005]
# Number of val years 1
# val years [1993]
#
#
# 12147600
# _____________________________
# Number of test years 0
# test years []
# Number of train years 13
# train years [1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2001, 2002, 2003, 2006]
# Number of val years 5
# val years [1982, 1987, 2000, 2004, 2007]
#
#
# 06623800
# _____________________________
# Number of test years 2
# test years [2010, 2011]
# Number of train years 13
# train years [1991, 1992, 1993, 1994, 1995, 1996, 1998, 1999, 2000, 2001, 2002, 2004, 2005]
# Number of val years 1
# val years [2014]
#
#
# 01123000
# _____________________________
# Number of test years 1
# test years [1982]
# Number of train years 13
# train years [1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2002, 2003, 2005]
# Number of val years 3
# val years [2001, 2009, 2010]
#
#
# 14138800
# _____________________________
# Number of test years 1
# test years [1996]
# Number of train years 13
# train years [1991, 1992, 1993, 1994, 1998, 1999, 2001, 2002, 2003, 2004, 2005, 2006, 2008]
# Number of val years 3
# val years [2000, 2011, 2014]
#
#
# 04074950
# _____________________________
# Number of test years 1
# test years [1996]
# Number of train years 13
# train years [1992, 1994, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008]
# Number of val years 2
# val years [1986, 1990]
#
#
# 09492400
# _____________________________
# Number of test years 2
# test years [1984, 2006]
# Number of train years 13
# train years [1991, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2009]
# Number of val years 1
# val years [1992]
#
#
# 11141280
# _____________________________
# Number of test years 0
# test years []
# Number of train years 13
# train years [1991, 1992, 1993, 1994, 1996, 1997, 1998, 1999, 2000, 2002, 2003, 2004, 2007]
# Number of val years 2
# val years [1995, 2005]
#
#
# 06289000
# _____________________________
# Number of test years 1
# test years [2018]
# Number of train years 13
# train years [1991, 1992, 1993, 1994, 1995, 1996, 1998, 1999, 2000, 2001, 2002, 2003, 2004]
# Number of val years 2
# val years [1997, 2014]
#
#
# 01669000
# _____________________________
# Number of test years 2
# test years [2011, 2019]
# Number of train years 13
# train years [1991, 1992, 1993, 1994, 1995, 1996, 1997, 2000, 2001, 2002, 2004, 2005, 2006]
# Number of val years 1
# val years [1999]
#
#
# 07301410
# _____________________________
# Number of test years 0
# test years []
# Number of train years 13
# train years [1991, 1992, 1993, 1994, 1996, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005]
# Number of val years 2
# val years [1997, 2015]
#
#
# 12117000
# _____________________________
# Number of test years 3
# test years [1987, 1996, 2007]
# Number of train years 13
# train years [1992, 1993, 1994, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2010, 2011]
# Number of val years 3
# val years [1984, 2009, 2016]
#
#
# 10336660
# _____________________________
# Number of test years 2
# test years [1997, 2006]
# Number of train years 13
# train years [1991, 1992, 1993, 1994, 1995, 1999, 2000, 2001, 2002, 2003, 2004, 2008, 2009]
# Number of val years 3
# val years [1982, 1986, 2017]
# 05120500
# _____________________________
# Number of test years 1
# test years [2009]
# Number of train years 13
# train years [1991, 1992, 1993, 1994, 1998, 2000, 2002, 2003, 2004, 2005, 2006, 2007, 2012]
# Number of val years 3
# val years [1995, 1996, 2011]
#
#
# 02324400
# _____________________________
# Number of test years 0
# test years []
# Number of train years 13
# train years [1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2004, 2005]
# Number of val years 1
# val years [2003]
#
#
# 02312200
# _____________________________
# Number of test years 0
# test years []
# Number of train years 13
# train years [1991, 1992, 1993, 1994, 1995, 1997, 1999, 2000, 2001, 2002, 2005, 2006, 2007]
# Number of val years 1
# val years [2019]
#
#
# 06221400
# _____________________________
# Number of test years 1
# test years [2017]
# Number of train years 13
# train years [1991, 1992, 1993, 1994, 1996, 1998, 2000, 2001, 2002, 2003, 2005, 2006, 2007]
# Number of val years 3
# val years [2004, 2018, 2019]
#
#
# 01487000
# _____________________________
# Number of test years 0
# test years []
# Number of train years 13
# train years [1991, 1992, 1993, 1995, 1996, 1997, 2000, 2001, 2002, 2004, 2005, 2006, 2008]
# Number of val years 5
# val years [1994, 1999, 2010, 2011, 2016]
#
#
# 11284400
# _____________________________
# Number of test years 0
# test years []
# Number of train years 13
# train years [1991, 1992, 1993, 1994, 1995, 1996, 1998, 1999, 2000, 2001, 2002, 2003, 2004]
# Number of val years 0
# val years []
#
#
# 06632400
# _____________________________
# Number of test years 3
# test years [1983, 2009, 2010]
# Number of train years 13
# train years [1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2004]
# Number of val years 1
# val years [2003]
#
#
# 06037500
# _____________________________
# Number of test years 5
# test years [1986, 1993, 1996, 1997, 2011]
# Number of train years 11
# train years [2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2013, 2014]
# Number of val years 1
# val years [1999]
#
#
# 01613050
# _____________________________
# Number of test years 1
# test years [2004]
# Number of train years 13
# train years [1991, 1992, 1995, 1997, 1999, 2000, 2001, 2002, 2006, 2007, 2008, 2009, 2010]
# Number of val years 2
# val years [1988, 1996]
#
#
# 10258000
# _____________________________
# Number of test years 1
# test years [2019]
# Number of train years 13
# train years [1991, 1992, 1994, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2006]
# Number of val years 4
# val years [1981, 1993, 1995, 2005]
#
#
# 02310947
# _____________________________
# Number of test years 1
# test years [1998]
# Number of train years 13
# train years [1991, 1992, 1993, 1994, 1995, 1996, 2000, 2002, 2003, 2006, 2007, 2008, 2009]
# Number of val years 3
# val years [1987, 2001, 2017]
#
#
# 02381600
# _____________________________
# Number of test years 1
# test years [2013]
# Number of train years 13
# train years [1991, 1992, 1993, 1994, 1995, 1997, 1998, 1999, 2000, 2001, 2002, 2005, 2006]
# Number of val years 2
# val years [2003, 2004]
#
#
# 11475560
# _____________________________
# Number of test years 1
# test years [1997]
# Number of train years 13
# train years [1991, 1992, 1994, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2007, 2008, 2009]
# Number of val years 1
# val years [1993]
#
#
# 14158500
# _____________________________
# Number of test years 0
# test years []
# Number of train years 13
# train years [1991, 1992, 1993, 1994, 1995, 1998, 1999, 2001, 2002, 2003, 2004, 2005, 2007]
# Number of val years 2
# val years [1996, 1997]
#
#
# 11253310
# _____________________________
# Number of test years 1
# test years [1983]
# Number of train years 13
# train years [1992, 1994, 1996, 1997, 1999, 2000, 2002, 2003, 2004, 2006, 2007, 2008, 2009]
# Number of val years 4
# val years [1990, 1991, 1993, 1995]
#
#
# 01142500
# _____________________________
# Number of test years 3
# test years [1998, 2011, 2019]
# Number of train years 13
# train years [1991, 1992, 1993, 1994, 1995, 1996, 2000, 2003, 2004, 2005, 2006, 2008, 2009]
# Number of val years 2
# val years [2007, 2013]
#
#
# 04124000
# _____________________________
# Number of test years 1
# test years [2014]
# Number of train years 13
# train years [1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003]
# Number of val years 2
# val years [1990, 2008]
#
#
# 11230500
# _____________________________
# Number of test years 2
# test years [1982, 2018]
# Number of train years 13
# train years [1991, 1992, 1993, 1994, 1996, 1998, 1999, 2000, 2001, 2002, 2004, 2005, 2007]
# Number of val years 5
# val years [1986, 1995, 1997, 2011, 2017]
#
#
# 01485500
# _____________________________
# Number of test years 4
# test years [1989, 1998, 2016, 2018]
# Number of train years 13
# train years [1991, 1992, 1995, 1996, 2001, 2002, 2003, 2004, 2006, 2007, 2008, 2009, 2011]
# Number of val years 3
# val years [1994, 2010, 2017]
#
#
# 06339100
# _____________________________
# Number of test years 0
# test years []
# Number of train years 13
# train years [1991, 1992, 1993, 1994, 1995, 1996, 1998, 1999, 2000, 2001, 2002, 2004, 2005]
# Number of val years 2
# val years [1997, 2003]
#
#
# 08378500
# _____________________________
# Number of test years 2
# test years [1991, 2013]
# Number of train years 13
# train years [1994, 1996, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2006, 2007, 2008, 2009]
# Number of val years 2
# val years [1995, 1997]
#
#
# 04296000
# _____________________________
# Number of test years 2
# test years [2002, 2011]
# Number of train years 13
# train years [1991, 1992, 1993, 1995, 1996, 1997, 1999, 2000, 2005, 2006, 2007, 2008, 2009]
# Number of val years 4
# val years [1982, 1994, 1998, 2014]
#
#
# 01658500
# _____________________________
# Number of test years 1
# test years [1989]
# Number of train years 13
# train years [1992, 1993, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2005, 2006, 2007]
# Number of val years 1
# val years [2008]
#
#
# 06431500
# _____________________________
# Number of test years 2
# test years [1982, 1995]
# Number of train years 13
# train years [1991, 1992, 1993, 1997, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2009]
# Number of val years 1
# val years [2013]
#
#
# 06344600
# _____________________________
# Number of test years 0
# test years []
# Number of train years 13
# train years [1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2004]
# Number of val years 1
# val years [2003]
#
#
# 14158790
# _____________________________
# Number of test years 1
# test years [1996]
# Number of train years 13
# train years [1991, 1992, 1993, 1994, 1998, 1999, 2001, 2002, 2003, 2004, 2005, 2006, 2007]
# Number of val years 3
# val years [1988, 2000, 2011]
#
#
# 05393500
# _____________________________
# Number of test years 1
# test years [1994]
# Number of train years 13
# train years [1991, 1998, 1999, 2000, 2001, 2003, 2004, 2006, 2007, 2008, 2009, 2012, 2013]
# Number of val years 5
# val years [1986, 1996, 2002, 2016, 2017]
#
#
# 01333000
# _____________________________
# Number of test years 2
# test years [2011, 2018]
# Number of train years 13
# train years [1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003]
# Number of val years 1
# val years [2019]
#
#
# 12115500
# _____________________________
# Number of test years 1
# test years [2007]
# Number of train years 13
# train years [1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004]
# Number of val years 5
# val years [1984, 1987, 1991, 2009, 2016]
#
#
# 10396000
# _____________________________
# Number of test years 1
# test years [2005]
# Number of train years 13
# train years [1991, 1992, 1994, 1995, 1996, 1999, 2000, 2001, 2002, 2003, 2007, 2008, 2010]
# Number of val years 5
# val years [1986, 1989, 1993, 1997, 1998]
#
#
# 11274630
# _____________________________
# Number of test years 1
# test years [1998]
# Number of train years 13
# train years [1991, 1992, 1993, 1994, 1996, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007]
# Number of val years 2
# val years [1995, 2017]
#
#
# 03076600
# _____________________________
# Number of test years 2
# test years [1996, 2000]
# Number of train years 13
# train years [1991, 1992, 1993, 1994, 1998, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009]
# Number of val years 1
# val years [2018]
#
#
# 09081600
# _____________________________
# Number of test years 2
# test years [1983, 2010]
# Number of train years 13
# train years [1991, 1992, 1994, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005]
# Number of val years 2
# val years [1995, 2011]
#
#
# 08324000
# _____________________________
# Number of test years 1
# test years [1985]
# Number of train years 13
# train years [1991, 1992, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004]
# Number of val years 1
# val years [1993]
#
#
# 10242000
# _____________________________
# Number of test years 1
# test years [1985]
# Number of train years 13
# train years [1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2002, 2003, 2004]
# Number of val years 1
# val years [1989]
# 05123400
# _____________________________
# Number of test years 0
# test years []
# Number of train years 13
# train years [1991, 1992, 1993, 1994, 1997, 1998, 2000, 2002, 2003, 2004, 2007, 2008, 2010]
# Number of val years 4
# val years [1999, 2005, 2011, 2017]
#
#
# 11237500
# _____________________________
# Number of test years 2
# test years [1996, 1997]
# Number of train years 13
# train years [1991, 1992, 1994, 1999, 2000, 2001, 2002, 2003, 2004, 2007, 2008, 2009, 2010]
# Number of val years 3
# val years [2006, 2017, 2018]
#
#
# 01545600
# _____________________________
# Number of test years 1
# test years [1994]
# Number of train years 13
# train years [1991, 1992, 1998, 1999, 2000, 2001, 2002, 2003, 2005, 2006, 2007, 2008, 2009]
# Number of val years 4
# val years [1984, 1996, 1997, 2004]
#
#
# 06224000
# _____________________________
# Number of test years 4
# test years [1981, 2010, 2011, 2017]
# Number of train years 13
# train years [1992, 1993, 1994, 1996, 1997, 1998, 2000, 2001, 2002, 2003, 2004, 2005, 2006]
# Number of val years 2
# val years [1991, 2019]
#
#
# 03011800
# _____________________________
# Number of test years 0
# test years []
# Number of train years 13
# train years [1991, 1992, 1993, 1995, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005]
# Number of val years 6
# val years [1980, 1984, 1989, 1994, 1996, 2011]
#
#
# 05087500
# _____________________________
# Number of test years 2
# test years [1996, 1997]
# Number of train years 13
# train years [1991, 1992, 1993, 1994, 2000, 2003, 2004, 2007, 2008, 2009, 2010, 2011, 2012]
# Number of val years 1
# val years [2006]
#
#
# 01134500
# _____________________________
# Number of test years 3
# test years [1987, 1995, 2014]
# Number of train years 13
# train years [1991, 1992, 1993, 1997, 1998, 1999, 2000, 2002, 2003, 2004, 2005, 2006, 2007]
# Number of val years 2
# val years [1990, 2019]
#
#
# 04040500
# _____________________________
# Number of test years 2
# test years [1985, 2002]
# Number of train years 13
# train years [1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2005, 2006, 2007]
# Number of val years 2
# val years [2013, 2019]
#
#
# 03460000
# _____________________________
# Number of test years 0
# test years []
# Number of train years 13
# train years [1991, 1992, 1993, 1995, 1997, 1998, 1999, 2000, 2001, 2002, 2004, 2005, 2006]
# Number of val years 2
# val years [1994, 2003]
#
#
# 07208500
# _____________________________
# Number of test years 0
# test years []
# Number of train years 13
# train years [1992, 1993, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2005, 2006, 2007]
# Number of val years 3
# val years [1995, 2010, 2015]
#
#
# 01414500
# _____________________________
# Number of test years 3
# test years [1996, 2001, 2011]
# Number of train years 12
# train years [1991, 1992, 1993, 1994, 1998, 2003, 2006, 2007, 2008, 2009, 2013, 2014]
# Number of val years 3
# val years [1980, 1997, 2004]
#
#
# 08380500
# _____________________________
# Number of test years 0
# test years []
# Number of train years 13
# train years [1992, 1993, 1995, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006]
# Number of val years 3
# val years [1991, 1996, 2013]
#
#
# 02300700
# _____________________________
# Number of test years 1
# test years [2001]
# Number of train years 13
# train years [1992, 1993, 1994, 1995, 1996, 1999, 2005, 2006, 2007, 2008, 2009, 2010, 2011]
# Number of val years 3
# val years [1988, 1997, 2012]
#
#
# 06464500
# _____________________________
# Number of test years 1
# test years [2019]
# Number of train years 13
# train years [1991, 1992, 1996, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2008]
# Number of val years 1
# val years [1997]
#
#
# 11224500
# _____________________________
# Number of test years 1
# test years [1995]
# Number of train years 13
# train years [1991, 1999, 2000, 2002, 2003, 2004, 2006, 2007, 2008, 2009, 2010, 2011, 2012]
# Number of val years 2
# val years [1983, 1993]
#
#
# 01557500
# _____________________________
# Number of test years 0
# test years []
# Number of train years 13
# train years [1991, 1992, 1993, 1995, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2005, 2007]
# Number of val years 7
# val years [1994, 1996, 2004, 2006, 2011, 2015, 2018]
#
#
# 14141500
# _____________________________
# Number of test years 2
# test years [1996, 2000]
# Number of train years 13
# train years [1991, 1992, 1993, 1994, 1998, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2010]
# Number of val years 2
# val years [1986, 2009]
#
#
# 04122200
# _____________________________
# Number of test years 1
# test years [1986]
# Number of train years 13
# train years [1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003]
# Number of val years 4
# val years [2014, 2015, 2018, 2019]
#
#
# 01516500
# _____________________________
# Number of test years 3
# test years [1994, 1996, 2011]
# Number of train years 13
# train years [1991, 1992, 1998, 1999, 2000, 2001, 2002, 2003, 2005, 2006, 2007, 2008, 2009]
# Number of val years 1
# val years [2018]
#
#
# 01121000
# _____________________________
# Number of test years 1
# test years [2006]
# Number of train years 13
# train years [1991, 1992, 1993, 1994, 1995, 1997, 1999, 2000, 2001, 2002, 2003, 2004, 2008]
# Number of val years 5
# val years [1982, 1996, 1998, 2009, 2011]
#
#
# 02349900
# _____________________________
# Number of test years 2
# test years [1981, 1994]
# Number of train years 13
# train years [1991, 1992, 1996, 1997, 1999, 2000, 2001, 2002, 2003, 2006, 2007, 2008, 2010]
# Number of val years 2
# val years [1998, 2005]
#
#
# 12390700
# _____________________________
# Number of test years 1
# test years [1996]
# Number of train years 13
# train years [1991, 1992, 1993, 1994, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006]
# Number of val years 3
# val years [1981, 2008, 2017]
#
#
# 09352900
# _____________________________
# Number of test years 1
# test years [2007]
# Number of train years 13
# train years [1991, 1992, 1993, 1995, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003]
# Number of val years 1
# val years [2004]
#
#
# 04197100
# _____________________________
# Number of test years 2
# test years [2008, 2011]
# Number of train years 13
# train years [1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004]
# Number of val years 5
# val years [1981, 1991, 2007, 2009, 2017]
#
#
# 01078000
# _____________________________
# Number of test years 1
# test years [2006]
# Number of train years 13
# train years [1991, 1992, 1993, 1994, 1995, 1996, 1998, 1999, 2000, 2001, 2002, 2003, 2004]
# Number of val years 1
# val years [1987]
#
#
# 03049800
# _____________________________
# Number of test years 2
# test years [1986, 2004]
# Number of train years 13
# train years [1991, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2006, 2008]
# Number of val years 4
# val years [1987, 1992, 2018, 2019]
#
#
# 01415000
# _____________________________
# Number of test years 3
# test years [1996, 2004, 2011]
# Number of train years 13
# train years [1991, 1992, 1993, 1994, 1999, 2000, 2001, 2002, 2007, 2008, 2009, 2013, 2014]
# Number of val years 1
# val years [2006]
#
#
# 01139000
# _____________________________
# Number of test years 3
# test years [1984, 1997, 2011]
# Number of train years 13
# train years [1991, 1992, 1993, 1994, 1995, 2000, 2002, 2003, 2004, 2005, 2006, 2007, 2008]
# Number of val years 4
# val years [1996, 2014, 2017, 2019]
#
#
# 12488500
# _____________________________
# Number of test years 2
# test years [1981, 1996]
# Number of train years 13
# train years [1991, 1992, 1993, 1994, 1998, 2000, 2001, 2002, 2003, 2004, 2005, 2008, 2009]
# Number of val years 2
# val years [2007, 2016]
#
#
# 13011500
# _____________________________
# Number of test years 4
# test years [1983, 1997, 1999, 2006]
# Number of train years 13
# train years [1991, 1992, 1993, 1994, 1995, 2001, 2002, 2004, 2008, 2009, 2010, 2012, 2013]
# Number of val years 2
# val years [1981, 1996]
#
#
# 04122500
# _____________________________
# Number of test years 2
# test years [1986, 2014]
# Number of train years 13
# train years [1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003]
# Number of val years 0
# val years []
#
#
# 13331500
# _____________________________
# Number of test years 0
# test years []
# Number of train years 13
# train years [1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2004]
# Number of val years 2
# val years [2003, 2010]
#
#
# 03504000
# _____________________________
# Number of test years 2
# test years [2004, 2016]
# Number of train years 13
# train years [1991, 1992, 1993, 1994, 1996, 1997, 1999, 2000, 2001, 2002, 2006, 2007, 2008]
# Number of val years 1
# val years [2013]
#
#
# 12145500
# _____________________________
# Number of test years 4
# test years [1987, 1990, 1991, 2007]
# Number of train years 13
# train years [1993, 1994, 1995, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2005, 2010, 2011]
# Number of val years 3
# val years [1984, 1996, 2016]
#
#
# 03028000
# _____________________________
# Number of test years 3
# test years [1989, 1996, 2011]
# Number of train years 13
# train years [1992, 1993, 1994, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2008, 2013]
# Number of val years 1
# val years [2018]
# 01549500
# _____________________________
# Number of test years 1
# test years [1996]
# Number of train years 13
# train years [1991, 1992, 1998, 2000, 2001, 2002, 2003, 2006, 2007, 2008, 2009, 2010, 2012]
# Number of val years 2
# val years [1984, 1994]
#
#
# 14020000
# _____________________________
# Number of test years 2
# test years [1996, 1997]
# Number of train years 13
# train years [1992, 1994, 1999, 2000, 2001, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010]
# Number of val years 4
# val years [1986, 2013, 2014, 2017]
#
#
# 10258500
# _____________________________
# Number of test years 0
# test years []
# Number of train years 13
# train years [1991, 1991, 1992, 1996, 1997, 1999, 2000, 2001, 2003, 2003, 2004, 2008, 2008]
# Number of val years 4
# val years [1980, 1983, 1993, 2019]
#
#
# 01567500
# _____________________________
# Number of test years 3
# test years [1989, 2004, 2011]
# Number of train years 13
# train years [1991, 1992, 1993, 1994, 1995, 1996, 1998, 1999, 2000, 2001, 2002, 2007, 2008]
# Number of val years 2
# val years [1984, 2014]
#
#
# 05057200
# _____________________________
# Number of test years 0
# test years []
# Number of train years 13
# train years [1991, 1992, 1994, 1998, 2000, 2001, 2002, 2003, 2005, 2006, 2007, 2008, 2012]
# Number of val years 4
# val years [1997, 2004, 2009, 2011]
#
#
# 13313000
# _____________________________
# Number of test years 2
# test years [2008, 2010]
# Number of train years 13
# train years [1991, 1992, 1993, 1994, 1995, 1998, 1999, 2000, 2001, 2002, 2004, 2005, 2012]
# Number of val years 1
# val years [2017]
#
#
# 13011900
# _____________________________
# Number of test years 1
# test years [1981]
# Number of train years 13
# train years [1991, 1992, 1993, 1994, 1995, 1996, 1998, 2000, 2001, 2002, 2004, 2005, 2006]
# Number of val years 4
# val years [1982, 1997, 2011, 2017]
#
#
# 04233000
# _____________________________
# Number of test years 1
# test years [2011]
# Number of train years 12
# train years [1992, 1993, 1994, 1995, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2009]
# Number of val years 3
# val years [1991, 1996, 1997]
#
#
# 05454000
# _____________________________
# Number of test years 1
# test years [1993]
# Number of train years 13
# train years [1991, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006]
# Number of val years 1
# val years [2016]
#
#
# 10259200
# _____________________________
# Number of test years 0
# test years []
# Number of train years 13
# train years [1992, 1994, 1995, 1996, 1998, 1999, 2000, 2001, 2003, 2003, 2004, 2005, 2007]
# Number of val years 1
# val years [1984]
#
#
# 14138900
# _____________________________
# Number of test years 0
# test years []
# Number of train years 13
# train years [1991, 1992, 1993, 1994, 1995, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004]
# Number of val years 1
# val years [1996]
#
#
# 01439500
# _____________________________
# Number of test years 0
# test years []
# Number of train years 13
# train years [1991, 1992, 1993, 1994, 1995, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2007]
# Number of val years 5
# val years [1996, 2004, 2005, 2006, 2011]
#
#
# 10263500
# _____________________________
# Number of test years 0
# test years []
# Number of train years 13
# train years [1991, 1994, 1995, 1996, 1997, 1999, 2000, 2001, 2002, 2004, 2007, 2008, 2009]
# Number of val years 5
# val years [1980, 1983, 1993, 1998, 2005]
#
#
# 05056000
# _____________________________
# Number of test years 1
# test years [2011]
# Number of train years 13
# train years [1991, 1992, 1993, 1994, 1995, 1998, 2000, 2001, 2002, 2003, 2005, 2006, 2007]
# Number of val years 4
# val years [1996, 1997, 2009, 2013]
#
#
# 04059500
# _____________________________
# Number of test years 1
# test years [1996]
# Number of train years 13
# train years [1991, 1992, 1993, 1994, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006]
# Number of val years 1
# val years [1986]
#
#
# 13023000
# _____________________________
# Number of test years 1
# test years [1986]
# Number of train years 13
# train years [1991, 1992, 1993, 1994, 1995, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005]
# Number of val years 1
# val years [1997]
#
#
# 10329500
# _____________________________
# Number of test years 1
# test years [1986]
# Number of train years 13
# train years [1991, 1992, 1993, 1994, 1996, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005]
# Number of val years 4
# val years [1980, 1997, 2006, 2017]
#
#
# 01552500
# _____________________________
# Number of test years 2
# test years [2011, 2018]
# Number of train years 13
# train years [1991, 1992, 1993, 1994, 1995, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004]
# Number of val years 3
# val years [1996, 2006, 2010]
#
#
# 03500240
# _____________________________
# Number of test years 1
# test years [2004]
# Number of train years 13
# train years [1991, 1992, 1993, 1997, 1998, 1999, 2000, 2001, 2002, 2006, 2007, 2008, 2009]
# Number of val years 0
# val years []
#
#
# 01451800
# _____________________________
# Number of test years 1
# test years [1987]
# Number of train years 13
# train years [1991, 1992, 1993, 1994, 1995, 1998, 2000, 2001, 2002, 2005, 2007, 2008, 2009]
# Number of val years 2
# val years [1996, 1997]
#
#
# 02149000
# _____________________________
# Number of test years 0
# test years []
# Number of train years 13
# train years [1992, 1993, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2005, 2006]
# Number of val years 1
# val years [2004]
#
#
# 04045500
# _____________________________
# Number of test years 1
# test years [1985]
# Number of train years 13
# train years [1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2003, 2004]
# Number of val years 2
# val years [2014, 2019]
#
#
# 05593900
# _____________________________
# Number of test years 1
# test years [2010]
# Number of train years 13
# train years [1991, 1992, 1993, 1994, 1995, 1996, 1997, 1999, 2000, 2001, 2003, 2004, 2005]
# Number of val years 5
# val years [1990, 1998, 2002, 2008, 2016]
#
#
# 02143040
# _____________________________
# Number of test years 1
# test years [2004]
# Number of train years 13
# train years [1992, 1993, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2006, 2007, 2008]
# Number of val years 1
# val years [1991]
#
#
# 14166500
# _____________________________
# Number of test years 1
# test years [1996]
# Number of train years 13
# train years [1991, 1992, 1993, 1994, 1998, 2000, 2001, 2002, 2003, 2004, 2005, 2007, 2008]
# Number of val years 2
# val years [1999, 2012]
#
#
# 03237280
# _____________________________
# Number of test years 1
# test years [2008]
# Number of train years 13
# train years [1991, 1992, 1993, 1994, 1995, 1998, 1999, 2000, 2001, 2002, 2004, 2005, 2006]
# Number of val years 3
# val years [1997, 2003, 2017]
#
#
# 01547700
# _____________________________
# Number of test years 3
# test years [1984, 1996, 2004]
# Number of train years 12
# train years [1991, 1992, 1998, 1999, 2000, 2001, 2002, 2007, 2009, 2012, 2013, 2014]
# Number of val years 2
# val years [2008, 2017]
#
#
# 06477500
# _____________________________
# Number of test years 0
# test years []
# Number of train years 13
# train years [1991, 1992, 1993, 1994, 1996, 1998, 1999, 2000, 2002, 2003, 2004, 2005, 2006]
# Number of val years 1
# val years [2010]
#
#
# 12178100
# _____________________________
# Number of test years 1
# test years [1981]
# Number of train years 13
# train years [1991, 1992, 1993, 1994, 1995, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2005]
# Number of val years 3
# val years [1984, 1996, 2004]
#
#
# 01596500
# _____________________________
# Number of test years 2
# test years [1986, 1996]
# Number of train years 13
# train years [1991, 1992, 1993, 1994, 1998, 1999, 2001, 2002, 2004, 2005, 2006, 2007, 2008]
# Number of val years 4
# val years [1980, 2010, 2011, 2018]
#
#
# 05444000
# _____________________________
# Number of test years 1
# test years [2002]
# Number of train years 13
# train years [1991, 1992, 1993, 1994, 1995, 1996, 1998, 1999, 2004, 2005, 2006, 2007, 2008]
# Number of val years 0
# val years []
#
#
# 12114500
# _____________________________
# Number of test years 2
# test years [2007, 2016]
# Number of train years 13
# train years [1992, 1993, 1994, 1995, 1997, 1998, 2000, 2001, 2002, 2003, 2004, 2005, 2010]
# Number of val years 3
# val years [1991, 1996, 2009]
#
#
# 11098000
# _____________________________
# Number of test years 0
# test years []
# Number of train years 13
# train years [1991, 1994, 1996, 1997, 1999, 2000, 2001, 2002, 2003, 2004, 2006, 2007, 2008]
# Number of val years 4
# val years [1980, 1998, 2005, 2010]
#
#
# 02055100
# _____________________________
# Number of test years 1
# test years [1986]
# Number of train years 13
# train years [1991, 1992, 1993, 1994, 1995, 1996, 1997, 1999, 2000, 2001, 2002, 2005, 2006]
# Number of val years 0
# val years []
#
#
# 03241500
# _____________________________
# Number of test years 0
# test years []
# Number of train years 13
# train years [1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003]
# Number of val years 4
# val years [1981, 1983, 1989, 2014]
#
#
# 02038850
# _____________________________
# Number of test years 0
# test years []
# Number of train years 13
# train years [1991, 1992, 1993, 1995, 1997, 1998, 1999, 2000, 2001, 2002, 2004, 2005, 2006]
# Number of val years 3
# val years [1987, 1996, 2018]
# 12048000
# _____________________________
# Number of test years 1
# test years [2002]
# Number of train years 13
# train years [1993, 1994, 1996, 1998, 1999, 2000, 2005, 2006, 2007, 2008, 2009, 2010, 2012]
# Number of val years 4
# val years [1986, 1991, 1997, 2004]
#
#
# 03078000
# _____________________________
# Number of test years 1
# test years [1996]
# Number of train years 13
# train years [1991, 1992, 1993, 1994, 1998, 1999, 2001, 2002, 2004, 2005, 2006, 2007, 2008]
# Number of val years 2
# val years [1986, 2018]
#
#
# 04256000
# _____________________________
# Number of test years 2
# test years [1982, 1985]
# Number of train years 13
# train years [1991, 1995, 1997, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008]
# Number of val years 3
# val years [1984, 1993, 1998]
#
#
# 11476600
# _____________________________
# Number of test years 1
# test years [1997]
# Number of train years 13
# train years [1991, 1992, 1993, 1994, 1999, 2000, 2001, 2002, 2004, 2005, 2006, 2007, 2008]
# Number of val years 4
# val years [1983, 1995, 2003, 2013]
#
#
# 01187300
# _____________________________
# Number of test years 2
# test years [1980, 2011]
# Number of train years 13
# train years [1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003]
# Number of val years 3
# val years [1985, 1987, 2007]
#
#
# 03471500
# _____________________________
# Number of test years 1
# test years [1995]
# Number of train years 13
# train years [1991, 1992, 1997, 1998, 1999, 2000, 2002, 2005, 2006, 2007, 2008, 2009, 2010]
# Number of val years 3
# val years [1989, 1996, 2004]
#
#
# 02212600
# _____________________________
# Number of test years 2
# test years [1990, 1994]
# Number of train years 13
# train years [1992, 1997, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2010]
# Number of val years 2
# val years [1981, 1996]
#
#
# 04196800
# _____________________________
# Number of test years 2
# test years [2008, 2011]
# Number of train years 13
# train years [1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004]
# Number of val years 3
# val years [1991, 2006, 2014]
#
#
# 01365000
# _____________________________
# Number of test years 1
# test years [2011]
# Number of train years 13
# train years [1991, 1992, 1993, 1994, 1995, 1997, 1998, 1999, 2001, 2002, 2003, 2007, 2008]
# Number of val years 5
# val years [1980, 1984, 1987, 2000, 2005]
#
#
# 01491000
# _____________________________
# Number of test years 2
# test years [1999, 2011]
# Number of train years 13
# train years [1991, 1992, 1993, 1995, 1996, 2002, 2003, 2004, 2005, 2006, 2008, 2009, 2014]
# Number of val years 2
# val years [1997, 2001]
#
#
# 02017500
# _____________________________
# Number of test years 3
# test years [1986, 1996, 2004]
# Number of train years 13
# train years [1991, 1992, 1993, 1998, 1999, 2000, 2001, 2002, 2006, 2007, 2008, 2009, 2010]
# Number of val years 1
# val years [2003]
#
#
# 06468170
# _____________________________
# Number of test years 1
# test years [2011]
# Number of train years 13
# train years [1991, 1992, 1994, 1998, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008]
# Number of val years 1
# val years [2009]
#
#
# 04185000
# _____________________________
# Number of test years 3
# test years [1982, 2009, 2012]
# Number of train years 13
# train years [1992, 1993, 1994, 1995, 1996, 1997, 2000, 2001, 2002, 2003, 2004, 2005, 2006]
# Number of val years 1
# val years [1985]
#
#
# 03291780
# _____________________________
# Number of test years 3
# test years [1990, 2011, 2017]
# Number of train years 13
# train years [1992, 1993, 1994, 1996, 1997, 1999, 2000, 2002, 2003, 2004, 2005, 2006, 2007]
# Number of val years 2
# val years [1981, 2009]
#
#
# 03368000
# ...
# Number of val years 2
# val years [1993, 2013]
#
#
# 05507600
# _____________________________
# Number of test years 1
# test years [2008]
# Number of train years 13
# train years [1991, 1992, 1995, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2010]
# Number of val years 2
# val years [1993, 1996]
#
#
# 05508805
# _____________________________
# Number of test years 2
# test years [2008, 2010]
# Number of train years 13
# train years [1991, 1992, 1995, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006]
# Number of val years 1
# val years [1993]
#
#
# 05591550
# _____________________________
# Number of test years 1
# test years [2015]
# Number of train years 13
# train years [1991, 1992, 1994, 1995, 1997, 1998, 2000, 2001, 2003, 2005, 2007, 2009, 2010]
# Number of val years 0
# val years []
#
#
# 05592050
# _____________________________
# Number of test years 0
# test years []
# Number of train years 13
# train years [1991, 1992, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2003, 2004, 2005]
# Number of val years 3
# val years [1983, 1993, 2016]
#
#
# 05592575
# _____________________________
# Number of test years 0
# test years []
# Number of train years 13
# train years [1991, 1992, 1993, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2004, 2005]
# Number of val years 2
# val years [2011, 2015]
#
#
# 05595730
# _____________________________
# Number of test years 0
# test years []
# Number of train years 13
# train years [1991, 1992, 1993, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2007]
# Number of val years 5
# val years [1986, 1990, 1994, 1995, 1996]
#
#
# 06154410
# _____________________________
# Number of test years 0
# test years []
# Number of train years 13
# train years [1991, 1992, 1994, 1995, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005]
# Number of val years 1
# val years [2008]
#
#
# 06408700
# _____________________________
# Number of test years 1
# test years [2015]
# Number of train years 13
# train years [1991, 1992, 1993, 1994, 1995, 1996, 1997, 1999, 2000, 2002, 2003, 2004, 2005]
# Number of val years 3
# val years [2001, 2007, 2014]
#
#
# 06440200
# _____________________________
# Number of test years 2
# test years [1991, 2019]
# Number of train years 13
# train years [1993, 1994, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008]
# Number of val years 1
# val years [1996]
#
#
# 06468250
# _____________________________
# Number of test years 0
# test years []
# Number of train years 13
# train years [1991, 1992, 1994, 1995, 1998, 2000, 2002, 2003, 2005, 2006, 2007, 2008, 2012]
# Number of val years 2
# val years [2009, 2011]
#
#
# 06470800
# _____________________________
# Number of test years 1
# test years [2011]
# Number of train years 13
# train years [1991, 1992, 1993, 1994, 1995, 1996, 1999, 2000, 2001, 2002, 2003, 2004, 2005]
# Number of val years 4
# val years [1997, 1998, 2009, 2019]
#
#
# 06479215
# _____________________________
# Number of test years 0
# test years []
# Number of train years 13
# train years [1991, 1992, 1996, 1998, 1999, 2000, 2002, 2003, 2004, 2005, 2006, 2007, 2008]
# Number of val years 2
# val years [1986, 1997]
#
#
# 06479438
# _____________________________
# Number of test years 2
# test years [1997, 2001]
# Number of train years 13
# train years [1992, 1994, 1995, 1999, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011]
# Number of val years 1
# val years [1986]
#
#
# 06614800
# _____________________________
# Number of test years 4
# test years [1995, 1996, 2010, 2011]
# Number of train years 13
# train years [1991, 1992, 1993, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007]
# Number of val years 1
# val years [1990]
#
#
# 06746095
# _____________________________
# Number of test years 2
# test years [1983, 1984]
# Number of train years 13
# train years [1991, 1992, 1994, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005]
# Number of val years 2
# val years [2017, 2019]
#
#
# 06803530
# _____________________________
# Number of test years 2
# test years [1987, 1993]
# Number of train years 13
# train years [1991, 1995, 1996, 1997, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2008]
# Number of val years 2
# val years [1982, 2014]
#
#
# 06879650
# _____________________________
# Number of test years 1
# test years [1995]
# Number of train years 13
# train years [1991, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2006, 2007, 2008, 2010, 2011]
# Number of val years 5
# val years [1982, 1992, 1993, 2004, 2016]
#
#
# 06906800
# _____________________________
# Number of test years 2
# test years [1994, 1995]
# Number of train years 13
# train years [1991, 1992, 1997, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008]
# Number of val years 2
# val years [1990, 1993]
#
#
# 06910800
# _____________________________
# Number of test years 1
# test years [1982]
# Number of train years 13
# train years [1991, 1994, 1996, 1997, 1998, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2008]
# Number of val years 3
# val years [1986, 1993, 1995]
#
#
# 07263295
# _____________________________
# Number of test years 0
# test years []
# Number of train years 13
# train years [1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003]
# Number of val years 4
# val years [2008, 2009, 2011, 2015]
#
#
# 07359610
# _____________________________
# Number of test years 2
# test years [1994, 2010]
# Number of train years 13
# train years [1991, 1992, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006]
# Number of val years 0
# val years []
#
#
# 07362587
# _____________________________
# Number of test years 1
# test years [2013]
# Number of train years 13
# train years [1992, 1993, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005]
# Number of val years 4
# val years [1990, 1991, 2008, 2011]
#
#
# 08023080
# _____________________________
# Number of test years 1
# test years [2016]
# Number of train years 13
# train years [1991, 1992, 1993, 1994, 1996, 1998, 2000, 2001, 2003, 2005, 2006, 2007, 2008]
# Number of val years 3
# val years [1989, 1999, 2002]
#
#
# 08050800
# _____________________________
# Number of test years 1
# test years [2007]
# Number of train years 13
# train years [1991, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2010]
# Number of val years 2
# val years [1994, 2016]
#
#
# 08070200
# _____________________________
# Number of test years 2
# test years [1995, 2017]
# Number of train years 13
# train years [1991, 1992, 1993, 1997, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008]
# Number of val years 2
# val years [1999, 2019]
#
#
# 08155200
# _____________________________
# Number of test years 0
# test years []
# Number of train years 13
# train years [1991, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2003, 2004, 2006]
# Number of val years 4
# val years [2002, 2005, 2016, 2019]
#
#
# 08158700
# _____________________________
# Number of test years 0
# test years []
# Number of train years 13
# train years [1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 2000, 2001, 2003, 2004, 2006]
# Number of val years 0
# val years []
#
#
# 08158810
# _____________________________
# Number of test years 0
# test years []
# Number of train years 13
# train years [1991, 1993, 1994, 1995, 1996, 1997, 1998, 2000, 2001, 2003, 2004, 2006, 2007]
# Number of val years 1
# val years [2019]
#
#
# 08164600
# _____________________________
# Number of test years 0
# test years []
# Number of train years 13
# train years [1992, 1993, 1994, 1996, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006]
# Number of val years 3
# val years [1981, 1991, 1995]
#
#
# 08176900
# _____________________________
# Number of test years 0
# test years []
# Number of train years 13
# train years [1991, 1992, 1993, 1994, 1996, 1998, 1999, 2000, 2002, 2003, 2004, 2005, 2006]
# Number of val years 0
# val years []
#
#
# 08178880
# _____________________________
# Number of test years 1
# test years [2002]
# Number of train years 13
# train years [1991, 1992, 1993, 1994, 1995, 1996, 1998, 1999, 2000, 2005, 2006, 2007, 2008]
# Number of val years 2
# val years [1987, 1997]
#
#
# 09035800
# _____________________________
# Number of test years 2
# test years [1983, 1984]
# Number of train years 13
# train years [1991, 1992, 1993, 1994, 1996, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005]
# Number of val years 0
# val years []
#
#
# 09107000
# _____________________________
# Number of test years 1
# test years [1995]
# Number of train years 13
# train years [1991, 1992, 1993, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007]
# Number of val years 1
# val years [2008]
#
#
# 09306242
# _____________________________
# Number of test years 2
# test years [1983, 1984]
# Number of train years 13
# train years [1991, 1992, 1993, 1994, 1996, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005]
# Number of val years 2
# val years [1981, 1985]
#
#
# 09378170
# _____________________________
# Number of test years 0
# test years []
# Number of train years 13
# train years [1991, 1992, 1993, 1994, 1997, 1998, 1999, 2001, 2003, 2004, 2005, 2006, 2007]
# Number of val years 2
# val years [1988, 2018]
# 09386900
# _____________________________
# Number of test years 1
# test years [1995]
# Number of train years 13
# train years [1991, 1992, 1993, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008]
# Number of val years 1
# val years [1998]
#
#
# 09447800
# _____________________________
# Number of test years 2
# test years [1984, 1993]
# Number of train years 13
# train years [1991, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2007, 2008]
# Number of val years 0
# val years []
#
#
# 09508300
# _____________________________
# Number of test years 0
# test years []
# Number of train years 13
# train years [1991, 1992, 1994, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2006]
# Number of val years 4
# val years [1980, 1993, 2005, 2010]
#
#
# 09512280
# _____________________________
# Number of test years 0
# test years []
# Number of train years 13
# train years [1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2009, 2011]
# Number of val years 4
# val years [1993, 2005, 2010, 2014]
#
#
# 10166430
# _____________________________
# Number of test years 1
# test years [1998]
# Number of train years 13
# train years [1991, 1992, 1993, 1994, 1995, 1996, 2000, 2001, 2002, 2003, 2004, 2006, 2008]
# Number of val years 1
# val years [2011]
#
#
# 10336645
# _____________________________
# Number of test years 1
# test years [2017]
# Number of train years 13
# train years [1991, 1992, 1993, 1994, 1995, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005]
# Number of val years 3
# val years [1982, 1997, 2006]
#
#
# 10336740
# _____________________________
# Number of test years 0
# test years []
# Number of train years 13
# train years [1991, 1992, 1993, 1994, 2000, 2001, 2002, 2003, 2004, 2005, 2007, 2008, 2009]
# Number of val years 2
# val years [1997, 1998]
#
#
# 10348850
# _____________________________
# Number of test years 1
# test years [1997]
# Number of train years 13
# train years [1991, 1992, 1993, 1994, 1995, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2007]
# Number of val years 0
# val years []
#
#
# 11148900
# _____________________________
# Number of test years 1
# test years [1993]
# Number of train years 13
# train years [1991, 1996, 1997, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008]
# Number of val years 2
# val years [1995, 1998]
#
#
# 11180960
# _____________________________
# Number of test years 0
# test years []
# Number of train years 13
# train years [1991, 1992, 1994, 1995, 1996, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2007]
# Number of val years 4
# val years [1982, 1983, 1997, 1998]
#
#
# 11299600
# _____________________________
# Number of test years 1
# test years [1986]
# Number of train years 13
# train years [1991, 1992, 1993, 1994, 1996, 1997, 1999, 2000, 2001, 2002, 2003, 2004, 2005]
# Number of val years 1
# val years [2017]
#
#
# 11451100
# _____________________________
# Number of test years 1
# test years [1997]
# Number of train years 13
# train years [1991, 1992, 1994, 1999, 2000, 2001, 2002, 2004, 2005, 2007, 2008, 2009, 2010]
# Number of val years 3
# val years [1986, 2006, 2019]
#
#
# 11480390
# _____________________________
# Number of test years 2
# test years [1986, 2006]
# Number of train years 13
# train years [1991, 1992, 1994, 1996, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2008, 2009]
# Number of val years 3
# val years [1982, 1993, 1997]
#
#
# 12043000
# _____________________________
# Number of test years 1
# test years [2007]
# Number of train years 13
# train years [1992, 1993, 1994, 1995, 1996, 1998, 1999, 2001, 2002, 2003, 2005, 2010, 2011]
# Number of val years 5
# val years [1991, 2000, 2004, 2008, 2009]
#
#
# 12143600
# _____________________________
# Number of test years 2
# test years [2007, 2009]
# Number of train years 13
# train years [1992, 1993, 1994, 1995, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005]
# Number of val years 1
# val years [2016]
#
#
# 12374250
# _____________________________
# Number of test years 2
# test years [2012, 2017]
# Number of train years 13
# train years [1991, 1992, 1993, 1994, 1995, 1998, 1999, 2000, 2001, 2003, 2004, 2005, 2006]
# Number of val years 2
# val years [2008, 2018]
#
#
# 12375900
# _____________________________
# Number of test years 1
# test years [2005]
# Number of train years 13
# train years [1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2007, 2008]
# Number of val years 1
# val years [1991]
#
#
# 12377150
# _____________________________
# Number of test years 2
# test years [1991, 2018]
# Number of train years 13
# train years [1993, 1994, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2004, 2006, 2007, 2008]
# Number of val years 0
# val years []
#
#
# 12381400
# _____________________________
# Number of test years 1
# test years [1997]
# Number of train years 13
# train years [1991, 1992, 1993, 1994, 1995, 1999, 2000, 2001, 2002, 2003, 2004, 2006, 2007]
# Number of val years 2
# val years [2011, 2018]
#
#
# 12383500
# _____________________________
# Number of test years 1
# test years [1982]
# Number of train years 13
# train years [1991, 1992, 1993, 1994, 1995, 1996, 1998, 2000, 2001, 2002, 2004, 2006, 2007]
# Number of val years 1
# val years [2005]
#
#
# 12388400
# _____________________________
# Number of test years 1
# test years [1997]
# Number of train years 12
# train years [1992, 1993, 1994, 1995, 2000, 2001, 2003, 2004, 2005, 2006, 2007, 2010]
# Number of val years 2
# val years [1991, 2008]
#
#
# 13310700
# _____________________________
# Number of test years 1
# test years [2010]
# Number of train years 13
# train years [1991, 1992, 1993, 1994, 1995, 1998, 2000, 2001, 2002, 2004, 2005, 2007, 2013]
# Number of val years 4
# val years [1997, 2006, 2008, 2012]
#
#
# 14092750
# _____________________________
# Number of test years 1
# test years [1996]
# Number of train years 13
# train years [1991, 1992, 1993, 1994, 1998, 1999, 2001, 2002, 2003, 2004, 2005, 2006, 2007]
# Number of val years 1
# val years [2000]
#
#
# 14096850
# _____________________________
# Number of test years 1
# test years [1996]
# Number of train years 13
# train years [1991, 1992, 1993, 1994, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2007]
# Number of val years 2
# val years [1986, 1997]
#
#
# 14138870
# _____________________________
# Number of test years 1
# test years [2000]
# Number of train years 13
# train years [1991, 1992, 1993, 1994, 1995, 1997, 1998, 2002, 2003, 2004, 2005, 2006, 2008]
# Number of val years 3
# val years [1986, 2009, 2011]
#
#
# 14139800
# _____________________________
# Number of test years 2
# test years [1996, 2011]
# Number of train years 13
# train years [1991, 1992, 1993, 1994, 1998, 1999, 2001, 2002, 2003, 2004, 2005, 2006, 2008]
# Number of val years 4
# val years [1989, 2000, 2007, 2009]
#
#
# 14303200
# _____________________________
# Number of test years 1
# test years [1996]
# Number of train years 13
# train years [1991, 1992, 1993, 1994, 1998, 2001, 2002, 2003, 2004, 2005, 2006, 2010, 2011]
# Number of val years 4
# val years [1999, 2007, 2015, 2016]
#
#
# 14306340
# _____________________________
# Number of test years 2
# test years [1996, 2012]
# Number of train years 13
# train years [1991, 1992, 1993, 1994, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2007]
# Number of val years 2
# val years [1997, 2008]
#
#
# 14308990
# _____________________________
# Number of test years 1
# test years [1995]
# Number of train years 13
# train years [1991, 1992, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008]
# Number of val years 4
# val years [1997, 2013, 2015, 2017]
#
#
# 14362250
# _____________________________
# Number of test years 1
# test years [1997]
# Number of train years 13
# train years [1991, 1992, 1993, 1994, 1999, 2000, 2001, 2002, 2004, 2005, 2007, 2008, 2009]
# Number of val years 2
# val years [2004, 2017]

# %%
minimum_train_years = 100
for i in split_these.n_years_list['train']:
    if i < minimum_train_years:
        minimum_train_years = i

# %%
print('average number of train years',np.nanmean(split_these.n_years_list['train']))
print('minimum number of train years',minimum_train_years)
print('average number of test years',np.nanmean(split_these.n_years_list['test']))
print('average number of val years',np.nanmean(split_these.n_years_list['val']))
# Out:
# average number of train years 12.958271236959762
# minimum number of train years 10
# average number of test years 1.427719821162444
# average number of val years 2.299552906110283

# %%
split_these.clean_start_end_lists()

# %%
split_these.dates['train']['01539000']
# Out:
# {'start_dates': [Timestamp('1990-01-10 00:00:00'),
#   Timestamp('1996-01-10 00:00:00'),
#   Timestamp('2007-01-10 00:00:00')],
#  'end_dates': [Timestamp('1995-09-30 00:00:00'),
#   Timestamp('2003-09-30 00:00:00'),
#   Timestamp('2008-09-30 00:00:00')]}

# %%
split_these.dates['val']['01539000']
# Out:
# {'start_dates': [Timestamp('1995-01-10 00:00:00')],
#  'end_dates': [Timestamp('1996-09-30 00:00:00')]}

# %%
split_these.dates['test']['01539000']
# Out:
# {'start_dates': [Timestamp('2005-01-10 00:00:00'),
#   Timestamp('2010-01-10 00:00:00'),
#   Timestamp('2017-01-10 00:00:00')],
#  'end_dates': [Timestamp('2006-09-30 00:00:00'),
#   Timestamp('2011-09-30 00:00:00'),
#   Timestamp('2018-09-30 00:00:00')]}

# %%
with open('per_basin_train_periods_file.plk', 'wb') as fb:
    pickle.dump(split_these.dates['train'], fb, protocol=pickle.HIGHEST_PROTOCOL)
with open('per_basin_test_periods_file.plk', 'wb') as fb:
    pickle.dump(split_these.dates['test'], fb, protocol=pickle.HIGHEST_PROTOCOL)
with open('per_basin_val_periods_file.plk', 'wb') as fb:
    pickle.dump(split_these.dates['val'], fb, protocol=pickle.HIGHEST_PROTOCOL)

# %%
split_these.dates['train']['01142500']
# Out:
# {'start_dates': [Timestamp('1990-01-10 00:00:00'),
#   Timestamp('1999-01-10 00:00:00'),
#   Timestamp('2002-01-10 00:00:00'),
#   Timestamp('2007-01-10 00:00:00')],
#  'end_dates': [Timestamp('1996-09-30 00:00:00'),
#   Timestamp('2000-09-30 00:00:00'),
#   Timestamp('2006-09-30 00:00:00'),
#   Timestamp('2009-09-30 00:00:00')]}
